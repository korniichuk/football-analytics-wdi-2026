# %% [markdown]
# ### **Sportmonks: Fixture (match) events**

# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv(".env")

API_TOKEN = os.getenv("API_TOKEN")
params = {"api_token": API_TOKEN, "include": "events"}

# %%
data = requests.get("https://api.sportmonks.com/v3/football/fixtures/19427866", params=params).json()["data"]
match = pd.json_normalize(data)

# %%
events = pd.json_normalize(match.events[0])
len(events)
# Out:
# 17

# %%
events.head(5)
# Out:
#           id  fixture_id  period_id  participant_id  type_id section  \
# 0  152152369    19427866    6369214           18648       18   event
# 1  152152251    19427866    6369198           18660       14   event
# 2  152152198    19427866    6369198           18660       14   event
# 3  152152281    19427866    6369198           18660       14   event
# 4  152152363    19427866    6369214           18660       18   event
#
#    player_id  related_player_id    player_name  related_player_name  ...  \
# 0       4385            33793.0  Lubomir Satka          Ondrej Duda  ...
# 1       4783         37429246.0     Leroy Sané        Florian Wirtz  ...
# 2        942            31824.0   Serge Gnabry        Leon Goretzka  ...
# 3       4783         37429246.0     Leroy Sané        Florian Wirtz  ...
# 4    6306127         37582044.0   Felix Nmecha  Aleksandar Pavlovic  ...
#
#            addition minute extra_minute  injured on_bench coach_id  \
# 0  3rd Substitution     46         None     None    False     None
# 1          3rd Goal     36         None     None    False     None
# 2          2nd Goal     29         None     None    False     None
# 3          4th Goal     41         None     None    False     None
# 4  2nd Substitution     46         None     None    False     None
#
#    sub_type_id detailed_period_id  rescinded  sort_order
# 0          NaN            6369214       None           3
# 1       1521.0            6369198       None           3
# 2       1522.0            6369198       None           2
# 3       1521.0            6369198       None           4
# 4          NaN            6369214       None           2
#
# [5 rows x 22 columns]
