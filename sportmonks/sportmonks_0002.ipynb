# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv(".env")

API_TOKEN = os.getenv("API_TOKEN")
params = {"api_token": API_TOKEN}

# %% [markdown]
# #### Fixtures (matches) by date (`YYYY-MM-DD`)

# %%
date = "2025-11-17"
data= requests.get(f"https://api.sportmonks.com/v3/football/fixtures/date/{date}", params=params).json()["data"]
matches = pd.json_normalize(data)
matches.head(3)
# Out:
#          id  sport_id  league_id  season_id  stage_id  group_id aggregate_id  \
# 0  19602922         1       1082      25007  77475190       NaN         None
# 1  19602833         1       1082      25007  77475190       NaN         None
# 2  19602923         1       1082      25007  77475190       NaN         None
#
#    round_id  state_id  venue_id                             name  \
# 0       NaN         5   14531.0                  Vanuatu vs Fiji
# 1       NaN         5       NaN             Egypt B vs Algeria B
# 2       NaN         5   14514.0  Madagascar vs Equatorial Guinea
#
#            starting_at                      result_info  leg details  length  \
# 0  2025-11-17 06:00:00     Vanuatu won after full-time.  1/1    None    90.0
# 1  2025-11-17 14:00:00              Game ended in draw.  1/1    None     NaN
# 2  2025-11-17 14:00:00  Madagascar won after full-time.  1/1    None    90.0
#
#    placeholder  has_odds  has_premium_odds  starting_at_timestamp
# 0        False     False             False             1763359200
# 1        False     False             False             1763388000
# 2        False     False             False             1763388000
