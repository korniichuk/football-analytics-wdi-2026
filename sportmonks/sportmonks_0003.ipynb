# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv(".env")

API_TOKEN = os.getenv("API_TOKEN")

# %% [markdown]
# #### Fixtures (matches) by date range (max 100 days)

# %%
start_date = "2025-11-17"
end_date = "2025-11-17"

data = []
page = 1
has_more = True

while has_more:
    params = {"api_token": API_TOKEN, "per_page": 50, "page": page}
    r = requests.get(f"https://api.sportmonks.com/v3/football/fixtures/between/{start_date}/{end_date}", params=params).json()
    data.extend(r["data"])
    has_more = r["pagination"]["has_more"]
    page += 1

# %%
matches = pd.json_normalize(data)
matches.head(13)
# Out:
#           id  sport_id  league_id  season_id  stage_id  group_id aggregate_id  \
# 0   19602922         1       1082      25007  77475190       NaN         None
# 1   19602833         1       1082      25007  77475190       NaN         None
# 2   19602923         1       1082      25007  77475190       NaN         None
# 3   19602924         1       1082      25007  77475190       NaN         None
# 4   19602925         1       1082      25007  77475190       NaN         None
# 5   19600070         1       1082      25007  77475190       NaN         None
# 6   19601159         1       1082      25007  77475190       NaN         None
# 7   19602828         1       1082      25007  77475190       NaN         None
# 8   19390596         1       1082      25007  77475190       NaN         None
# 9   19603712         1       1082      25007  77475190       NaN         None
# 10  19345768         1        720      21887  77464842  249217.0         None
# 11  19345769         1        720      21887  77464842  251897.0         None
# 12  19427866         1        720      21887  77464842  249211.0         None
#
#     round_id  state_id  venue_id                             name  \
# 0        NaN         5   14531.0                  Vanuatu vs Fiji
# 1        NaN         5       NaN             Egypt B vs Algeria B
# 2        NaN         5   14514.0  Madagascar vs Equatorial Guinea
# 3        NaN         5       NaN               Chad vs Mozambique
# 4        NaN         5  340207.0               Bahrain vs Somalia
# 5        NaN         5       NaN               Comoros vs Namibia
# 6        NaN         8  341836.0      Egypt vs Cape Verde Islands
# 7        NaN         5       NaN                Qatar vs Zimbabwe
# 8        NaN         5  343709.0               Finland vs Andorra
# 9        NaN         5       NaN            Morocco B vs Djibouti
# 10  362711.0         5     974.0                  Malta vs Poland
# 11  362711.0         5    1810.0      Czech Republic vs Gibraltar
# 12  362711.0         5    3876.0              Germany vs Slovakia
#
#             starting_at                          result_info  leg details  \
# 0   2025-11-17 06:00:00         Vanuatu won after full-time.  1/1    None
# 1   2025-11-17 14:00:00                  Game ended in draw.  1/1    None
# 2   2025-11-17 14:00:00      Madagascar won after full-time.  1/1    None
# 3   2025-11-17 15:00:00                  Game ended in draw.  1/1    None
# 4   2025-11-17 15:30:00         Somalia won after full-time.  1/1    None
# 5   2025-11-17 16:00:00         Comoros won after full-time.  1/1    None
# 6   2025-11-17 16:00:00           Egypt won after penalties.  1/1    None
# 7   2025-11-17 16:30:00        Zimbabwe won after full-time.  1/1    None
# 8   2025-11-17 17:00:00         Finland won after full-time.  1/1    None
# 9   2025-11-17 17:00:00       Morocco B won after full-time.  1/1    None
# 10  2025-11-17 19:45:00          Poland won after full-time.  1/1    None
# 11  2025-11-17 19:45:00  Czech Republic won after full-time.  1/1    None
# 12  2025-11-17 19:45:00         Germany won after full-time.  1/1    None
#
#     length  placeholder  has_odds  has_premium_odds  starting_at_timestamp
# 0     90.0        False     False             False             1763359200
# 1      NaN        False     False             False             1763388000
# 2     90.0        False     False             False             1763388000
# 3     90.0        False      True              True             1763391600
# 4     90.0        False      True              True             1763393400
# 5     90.0        False      True              True             1763395200
# 6      NaN        False      True              True             1763395200
# 7      NaN        False      True              True             1763397000
# 8     90.0        False      True              True             1763398800
# 9     90.0        False     False             False             1763398800
# 10    90.0        False      True              True             1763408700
# 11    90.0        False      True              True             1763408700
# 12    90.0        False      True              True             1763408700
